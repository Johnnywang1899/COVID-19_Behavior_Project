# %%
# Import library
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error

# %%
# Load in dataframe
df = pd.read_csv("COVID-19BehaviorData_CAN_USA.csv")

# %%
# Print the table of the data types for every variable in the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28825 entries, 0 to 28824
# Data columns (total 79 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Index               28825 non-null  int64
#  1   RecordNo            28825 non-null  object
#  2   endtime             28825 non-null  object
#  3   qweek               28825 non-null  object
#  4   i1_health           28825 non-null  int64
#  5   i2_health           28825 non-null  int64
#  6   i7a_health          28825 non-null  int64
#  7   i3_health           28825 non-null  object
#  8   i4_health           28825 non-null  object
#  9   i5_health_1         28825 non-null  object
#  10  i5_health_2         28825 non-null  object
#  11  i5_health_3         28825 non-null  object
#  12  i5_health_4         28825 non-null  object
#  13  i5_health_5         28825 non-null  object
#  14  i5_health_99        28825 non-null  object
#  15  i5a_health          28825 non-null  object
#  16  i6_health           28825 non-null  object
#  17  i7b_health          28825 non-null  object
#  18  i8_health           28825 non-null  object
#  19  i9_health           28825 non-null  object
#  20  i10_health          28825 non-null  object
#  21  i11_health          28825 non-null  object
#  22  i12_health_1        28825 non-null  object
#  23  i12_health_2        28825 non-null  object
#  24  i12_health_3        28825 non-null  object
#  25  i12_health_4        28825 non-null  object
#  26  i12_health_5        28825 non-null  object
#  27  i12_health_6        28825 non-null  object
#  28  i12_health_7        28825 non-null  object
#  29  i12_health_8        28825 non-null  object
#  30  i12_health_9        28825 non-null  object
#  31  i12_health_10       28825 non-null  object
#  32  i12_health_11       28825 non-null  object
#  33  i12_health_12       28825 non-null  object
#  34  i12_health_13       28825 non-null  object
#  35  i12_health_14       28825 non-null  object
#  36  i12_health_15       28825 non-null  object
#  37  i12_health_16       28825 non-null  object
#  38  i12_health_17       28825 non-null  object
#  39  i12_health_18       28825 non-null  object
#  40  i12_health_19       28825 non-null  object
#  41  i12_health_20       28825 non-null  object
#  42  i13_health          28825 non-null  int64
#  43  i14_health_1        28825 non-null  object
#  44  i14_health_2        28825 non-null  object
#  45  i14_health_3        28825 non-null  object
#  46  i14_health_4        28825 non-null  object
#  47  i14_health_5        28825 non-null  object
#  48  i14_health_6        28825 non-null  object
#  49  i14_health_7        28825 non-null  object
#  50  i14_health_8        28825 non-null  object
#  51  i14_health_9        28825 non-null  object
#  52  i14_health_10       28825 non-null  object
#  53  i14_health_96       28825 non-null  object
#  54  i14_health_98       28825 non-null  object
#  55  i14_health_99       28825 non-null  object
#  56  i14_health_other    28825 non-null  object
#  57  d1_health_1         28825 non-null  object
#  58  d1_health_2         28825 non-null  object
#  59  d1_health_3         28825 non-null  object
#  60  d1_health_4         28825 non-null  object
#  61  d1_health_5         28825 non-null  object
#  62  d1_health_6         28825 non-null  object
#  63  d1_health_7         28825 non-null  object
#  64  d1_health_8         28825 non-null  object
#  65  d1_health_9         28825 non-null  object
#  66  d1_health_10        28825 non-null  object
#  67  d1_health_11        28825 non-null  object
#  68  d1_health_12        28825 non-null  object
#  69  d1_health_13        28825 non-null  object
#  70  d1_health_98        28825 non-null  object
#  71  d1_health_99        28825 non-null  object
#  72  weight              28825 non-null  float64
#  73  gender              28825 non-null  object
#  74  age                 28825 non-null  int64
#  75  region_state        28825 non-null  object
#  76  household_size      28825 non-null  object
#  77  household_children  28825 non-null  object
#  78  employment_status   28825 non-null  object
# dtypes: float64(1), int64(6), object(72)
# memory usage: 17.4+ MB

# %%
df_final
# Out:
#        i1_health  i2_health  i7a_health  i3_health  i4_health  i5_health_1  \
# 103          NaN        NaN         NaN        NaN        NaN          NaN
# 110          NaN        NaN         NaN        NaN        NaN          NaN
# 127          NaN        NaN         NaN        NaN        NaN          NaN
# 128          NaN        NaN         NaN        NaN        NaN          NaN
# 134          NaN        NaN         NaN        NaN        NaN          NaN
# ...          ...        ...         ...        ...        ...          ...
# 28789        NaN        NaN         NaN        NaN        NaN          NaN
# 28805        NaN        NaN         NaN        NaN        NaN          NaN
# 28811        NaN        NaN         NaN        NaN        NaN          NaN
# 28814        NaN        NaN         NaN        NaN        NaN          NaN
# 28823        NaN        NaN         NaN        NaN        NaN          NaN
#
#        i5_health_2  i5_health_3  i5_health_4  i5_health_5  ...  d1_health_13  \
# 103            NaN          NaN          NaN          NaN  ...           NaN
# 110            NaN          NaN          NaN          NaN  ...           NaN
# 127            NaN          NaN          NaN          NaN  ...           NaN
# 128            NaN          NaN          NaN          NaN  ...           NaN
# 134            NaN          NaN          NaN          NaN  ...           NaN
# ...            ...          ...          ...          ...  ...           ...
# 28789          NaN          NaN          NaN          NaN  ...           NaN
# 28805          NaN          NaN          NaN          NaN  ...           NaN
# 28811          NaN          NaN          NaN          NaN  ...           NaN
# 28814          NaN          NaN          NaN          NaN  ...           NaN
# 28823          NaN          NaN          NaN          NaN  ...           NaN
#
#        d1_health_98  d1_health_99  weight  gender  age  region_state  \
# 103             NaN           NaN     NaN     NaN  NaN           NaN
# 110             NaN           NaN     NaN     NaN  NaN           NaN
# 127             NaN           NaN     NaN     NaN  NaN           NaN
# 128             NaN           NaN     NaN     NaN  NaN           NaN
# 134             NaN           NaN     NaN     NaN  NaN           NaN
# ...             ...           ...     ...     ...  ...           ...
# 28789           NaN           NaN     NaN     NaN  NaN           NaN
# 28805           NaN           NaN     NaN     NaN  NaN           NaN
# 28811           NaN           NaN     NaN     NaN  NaN           NaN
# 28814           NaN           NaN     NaN     NaN  NaN           NaN
# 28823           NaN           NaN     NaN     NaN  NaN           NaN
#
#        household_size  household_children  employment_status
# 103               NaN                 NaN                NaN
# 110               NaN                 NaN                NaN
# 127               NaN                 NaN                NaN
# 128               NaN                 NaN                NaN
# 134               NaN                 NaN                NaN
# ...               ...                 ...                ...
# 28789             NaN                 NaN                NaN
# 28805             NaN                 NaN                NaN
# 28811             NaN                 NaN                NaN
# 28814             NaN                 NaN                NaN
# 28823             NaN                 NaN                NaN
#
# [1795 rows x 75 columns]

# %%
# Exclude non-related features
df = df.drop(["Index", "RecordNo", "endtime", "qweek"], axis = 1)

# %%
df
# Out:
#        i1_health  i2_health  i7a_health                   i3_health  \
# 0              0          1           1              No, I have not
# 1              0          6           0              No, I have not
# 2              6          1           0              No, I have not
# 3              1          1           1              No, I have not
# 4              1          3           1              No, I have not
# ...          ...        ...         ...                         ...
# 28820          2          1           1              No, I have not
# 28821          1          1           0              No, I have not
# 28822          4          0           0              No, I have not
# 28823          1          0           1  Yes, and I tested negative
# 28824          5          0           6
#
#                            i4_health i5_health_1 i5_health_2 i5_health_3  \
# 0                  No, they have not          No          No          No
# 1                  No, they have not         Yes          No          No
# 2                  No, they have not          No          No          No
# 3                  No, they have not          No          No          No
# 4                  No, they have not          No          No          No
# ...                              ...         ...         ...         ...
# 28820              No, they have not          No          No          No
# 28821              No, they have not          No          No          No
# 28822              No, they have not          No          No          No
# 28823  Yes, and they tested negative          No          No          No
# 28824
#
#       i5_health_4 i5_health_5  ... d1_health_13 d1_health_98 d1_health_99  \
# 0              No          No  ...           No           No           No
# 1              No          No  ...           No           No          Yes
# 2              No         Yes  ...           No           No           No
# 3              No          No  ...           No           No           No
# 4              No          No  ...           No           No          Yes
# ...           ...         ...  ...          ...          ...          ...
# 28820          No          No  ...           No           No          Yes
# 28821          No          No  ...           No           No           No
# 28822          No          No  ...           No           No          Yes
# 28823          No          No  ...           No           No          Yes
# 28824                          ...           No           No          Yes
#
#          weight  gender age                            region_state  \
# 0      1.036370    Male  73  British Columbia / Colombie Britanique
# 1      1.016961  Female  37  British Columbia / Colombie Britanique
# 2      1.003516    Male  25                                 Ontario
# 3      1.002949    Male  66                                 Ontario
# 4      1.028216  Female  25  British Columbia / Colombie Britanique
# ...         ...     ...  ..                                     ...
# 28820  1.335790  Female  27                                Oklahoma
# 28821  1.413918  Female  74                              California
# 28822  1.044810  Female  26                            Rhode Island
# 28823  2.919237    Male  22                             Mississippi
# 28824  1.832323    Male  23                                   Texas
#
#           household_size household_children     employment_status
# 0                      1                  0               Retired
# 1                      1                  0            Unemployed
# 2              8 or more                  2  Full time employment
# 3                      2                  0               Retired
# 4                      2                  0            Unemployed
# ...                  ...                ...                   ...
# 28820                  3                  2  Full time employment
# 28821                  1                  0               Retired
# 28822                  4                  2  Full time employment
# 28823                  5                  0  Full time employment
# 28824  Prefer not to say  Prefer not to say                 Other
#
# [28825 rows x 75 columns]

# %%
# Filter out only the patients with confirmed results (negative or positive)
df_final = df[(df["i3_health"] == "Yes, and I tested negative") | (df["i3_health"] == "Yes, and I tested positive")]
df_final
# Out:
#        i1_health  i2_health  i7a_health                   i3_health  \
# 103            1          1           2  Yes, and I tested negative
# 110            2          5           2  Yes, and I tested negative
# 127            3         15           3  Yes, and I tested negative
# 128           10         10           1  Yes, and I tested positive
# 134            2         10           1  Yes, and I tested negative
# ...          ...        ...         ...                         ...
# 28789          2          2           2  Yes, and I tested negative
# 28805          5          4           2  Yes, and I tested positive
# 28811          0          2           2  Yes, and I tested negative
# 28814          1          2           2  Yes, and I tested negative
# 28823          1          0           1  Yes, and I tested negative
#
#                            i4_health i5_health_1 i5_health_2 i5_health_3  \
# 103    Yes, and they tested negative          No          No          No
# 110    Yes, and they tested negative          No          No          No
# 127    Yes, and they tested negative          No          No          No
# 128                No, they have not          No          No          No
# 134    Yes, and they tested negative          No          No          No
# ...                              ...         ...         ...         ...
# 28789  Yes, and they tested negative         Yes          No          No
# 28805  Yes, and they tested positive          No         Yes          No
# 28811  Yes, and they tested negative         Yes          No          No
# 28814  Yes, and they tested negative          No          No          No
# 28823  Yes, and they tested negative          No          No          No
#
#       i5_health_4 i5_health_5  ... d1_health_13 d1_health_98 d1_health_99  \
# 103            No          No  ...           No           No          Yes
# 110           Yes          No  ...           No           No           No
# 127            No          No  ...           No           No          Yes
# 128            No          No  ...           No           No           No
# 134            No          No  ...           No           No          Yes
# ...           ...         ...  ...          ...          ...          ...
# 28789          No         Yes  ...           No           No           No
# 28805          No          No  ...           No           No           No
# 28811         Yes          No  ...           No           No           No
# 28814          No          No  ...           No           No          Yes
# 28823          No          No  ...           No           No          Yes
#
#          weight  gender age     region_state household_size  \
# 103    1.007474    Male  54  Quebec / Québec     Don't know
# 110    1.012842    Male  34  Quebec / Québec              1
# 127    0.992531    Male  36          Ontario              4
# 128    0.994496  Female  64          Ontario              2
# 134    0.984166  Female  36          Ontario              3
# ...         ...     ...  ..              ...            ...
# 28789  0.683871    Male  26       Washington              5
# 28805  0.566747    Male  20         New York              6
# 28811  0.744511  Female  23             Ohio              4
# 28814  1.302322    Male  18         New York              5
# 28823  2.919237    Male  22      Mississippi              5
#
#       household_children     employment_status
# 103                    1  Full time employment
# 110                    1            Unemployed
# 127                    4  Full time employment
# 128                    0           Not working
# 134                    1  Full time employment
# ...                  ...                   ...
# 28789                  3     Full time student
# 28805                  3  Full time employment
# 28811                  2  Full time employment
# 28814                  2  Part time employment
# 28823                  0  Full time employment
#
# [1795 rows x 75 columns]

# %%
df_final
# Out:
#        i1_health  i2_health  i7a_health                   i3_health  \
# 103            1          1           2  Yes, and I tested negative
# 110            2          5           2  Yes, and I tested negative
# 127            3         15           3  Yes, and I tested negative
# 128           10         10           1  Yes, and I tested positive
# 134            2         10           1  Yes, and I tested negative
# ...          ...        ...         ...                         ...
# 28789          2          2           2  Yes, and I tested negative
# 28805          5          4           2  Yes, and I tested positive
# 28811          0          2           2  Yes, and I tested negative
# 28814          1          2           2  Yes, and I tested negative
# 28823          1          0           1  Yes, and I tested negative
#
#                            i4_health i5_health_1 i5_health_2 i5_health_3  \
# 103    Yes, and they tested negative          No          No          No
# 110    Yes, and they tested negative          No          No          No
# 127    Yes, and they tested negative          No          No          No
# 128                No, they have not          No          No          No
# 134    Yes, and they tested negative          No          No          No
# ...                              ...         ...         ...         ...
# 28789  Yes, and they tested negative         Yes          No          No
# 28805  Yes, and they tested positive          No         Yes          No
# 28811  Yes, and they tested negative         Yes          No          No
# 28814  Yes, and they tested negative          No          No          No
# 28823  Yes, and they tested negative          No          No          No
#
#       i5_health_4 i5_health_5  ... d1_health_13 d1_health_98 d1_health_99  \
# 103            No          No  ...           No           No          Yes
# 110           Yes          No  ...           No           No           No
# 127            No          No  ...           No           No          Yes
# 128            No          No  ...           No           No           No
# 134            No          No  ...           No           No          Yes
# ...           ...         ...  ...          ...          ...          ...
# 28789          No         Yes  ...           No           No           No
# 28805          No          No  ...           No           No           No
# 28811         Yes          No  ...           No           No           No
# 28814          No          No  ...           No           No          Yes
# 28823          No          No  ...           No           No          Yes
#
#          weight  gender age     region_state household_size  \
# 103    1.007474    Male  54  Quebec / Québec     Don't know
# 110    1.012842    Male  34  Quebec / Québec              1
# 127    0.992531    Male  36          Ontario              4
# 128    0.994496  Female  64          Ontario              2
# 134    0.984166  Female  36          Ontario              3
# ...         ...     ...  ..              ...            ...
# 28789  0.683871    Male  26       Washington              5
# 28805  0.566747    Male  20         New York              6
# 28811  0.744511  Female  23             Ohio              4
# 28814  1.302322    Male  18         New York              5
# 28823  2.919237    Male  22      Mississippi              5
#
#       household_children     employment_status
# 103                    1  Full time employment
# 110                    1            Unemployed
# 127                    4  Full time employment
# 128                    0           Not working
# 134                    1  Full time employment
# ...                  ...                   ...
# 28789                  3     Full time student
# 28805                  3  Full time employment
# 28811                  2  Full time employment
# 28814                  2  Part time employment
# 28823                  0  Full time employment
#
# [1795 rows x 75 columns]

# %%
enc_dict
# Out:
# {'Yes': 1, 'No': 0}

# %%
# Data cleaning
enc_dict = dict()
enc_dict["Yes"] = 1
enc_dict["No"] = 0
#enc_dict[" "] = np.nan

# %%
df_col = df_final.columns.tolist()

# %%
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1795 entries, 103 to 28823
# Data columns (total 75 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   i1_health           1795 non-null   int64
#  1   i2_health           1795 non-null   int64
#  2   i7a_health          1795 non-null   int64
#  3   i3_health           1795 non-null   object
#  4   i4_health           1795 non-null   object
#  5   i5_health_1         1795 non-null   object
#  6   i5_health_2         1795 non-null   object
#  7   i5_health_3         1795 non-null   object
#  8   i5_health_4         1795 non-null   object
#  9   i5_health_5         1795 non-null   object
#  10  i5_health_99        1795 non-null   object
#  11  i5a_health          1795 non-null   object
#  12  i6_health           1795 non-null   object
#  13  i7b_health          1795 non-null   object
#  14  i8_health           1795 non-null   object
#  15  i9_health           1795 non-null   object
#  16  i10_health          1795 non-null   object
#  17  i11_health          1795 non-null   object
#  18  i12_health_1        1795 non-null   object
#  19  i12_health_2        1795 non-null   object
#  20  i12_health_3        1795 non-null   object
#  21  i12_health_4        1795 non-null   object
#  22  i12_health_5        1795 non-null   object
#  23  i12_health_6        1795 non-null   object
#  24  i12_health_7        1795 non-null   object
#  25  i12_health_8        1795 non-null   object
#  26  i12_health_9        1795 non-null   object
#  27  i12_health_10       1795 non-null   object
#  28  i12_health_11       1795 non-null   object
#  29  i12_health_12       1795 non-null   object
#  30  i12_health_13       1795 non-null   object
#  31  i12_health_14       1795 non-null   object
#  32  i12_health_15       1795 non-null   object
#  33  i12_health_16       1795 non-null   object
#  34  i12_health_17       1795 non-null   object
#  35  i12_health_18       1795 non-null   object
#  36  i12_health_19       1795 non-null   object
#  37  i12_health_20       1795 non-null   object
#  38  i13_health          1795 non-null   int64
#  39  i14_health_1        1795 non-null   object
#  40  i14_health_2        1795 non-null   object
#  41  i14_health_3        1795 non-null   object
#  42  i14_health_4        1795 non-null   object
#  43  i14_health_5        1795 non-null   object
#  44  i14_health_6        1795 non-null   object
#  45  i14_health_7        1795 non-null   object
#  46  i14_health_8        1795 non-null   object
#  47  i14_health_9        1795 non-null   object
#  48  i14_health_10       1795 non-null   object
#  49  i14_health_96       1795 non-null   object
#  50  i14_health_98       1795 non-null   object
#  51  i14_health_99       1795 non-null   object
#  52  i14_health_other    1795 non-null   object
#  53  d1_health_1         1795 non-null   object
#  54  d1_health_2         1795 non-null   object
#  55  d1_health_3         1795 non-null   object
#  56  d1_health_4         1795 non-null   object
#  57  d1_health_5         1795 non-null   object
#  58  d1_health_6         1795 non-null   object
#  59  d1_health_7         1795 non-null   object
#  60  d1_health_8         1795 non-null   object
#  61  d1_health_9         1795 non-null   object
#  62  d1_health_10        1795 non-null   object
#  63  d1_health_11        1795 non-null   object
#  64  d1_health_12        1795 non-null   object
#  65  d1_health_13        1795 non-null   object
#  66  d1_health_98        1795 non-null   object
#  67  d1_health_99        1795 non-null   object
#  68  weight              1795 non-null   float64
#  69  gender              1795 non-null   object
#  70  age                 1795 non-null   int64
#  71  region_state        1795 non-null   object
#  72  household_size      1795 non-null   object
#  73  household_children  1795 non-null   object
#  74  employment_status   1795 non-null   object
# dtypes: float64(1), int64(5), object(69)
# memory usage: 1.0+ MB

# %%
df_final['i5_health_1'].apply(lambda x: enc_dict[x] if x in enc_dict.keys() else x).value_counts()
# Out:
# 0    1489
# 1     247
#        59
# Name: i5_health_1, dtype: int64

# %%
df_final
# Out:
#        i1_health  i2_health  i7a_health                   i3_health  \
# 103            1          1           2  Yes, and I tested negative
# 110            2          5           2  Yes, and I tested negative
# 127            3         15           3  Yes, and I tested negative
# 128           10         10           1  Yes, and I tested positive
# 134            2         10           1  Yes, and I tested negative
# ...          ...        ...         ...                         ...
# 28789          2          2           2  Yes, and I tested negative
# 28805          5          4           2  Yes, and I tested positive
# 28811          0          2           2  Yes, and I tested negative
# 28814          1          2           2  Yes, and I tested negative
# 28823          1          0           1  Yes, and I tested negative
#
#                            i4_health i5_health_1 i5_health_2 i5_health_3  \
# 103    Yes, and they tested negative          No          No          No
# 110    Yes, and they tested negative          No          No          No
# 127    Yes, and they tested negative          No          No          No
# 128                No, they have not          No          No          No
# 134    Yes, and they tested negative          No          No          No
# ...                              ...         ...         ...         ...
# 28789  Yes, and they tested negative         Yes          No          No
# 28805  Yes, and they tested positive          No         Yes          No
# 28811  Yes, and they tested negative         Yes          No          No
# 28814  Yes, and they tested negative          No          No          No
# 28823  Yes, and they tested negative          No          No          No
#
#       i5_health_4 i5_health_5  ... d1_health_13 d1_health_98 d1_health_99  \
# 103            No          No  ...           No           No          Yes
# 110           Yes          No  ...           No           No           No
# 127            No          No  ...           No           No          Yes
# 128            No          No  ...           No           No           No
# 134            No          No  ...           No           No          Yes
# ...           ...         ...  ...          ...          ...          ...
# 28789          No         Yes  ...           No           No           No
# 28805          No          No  ...           No           No           No
# 28811         Yes          No  ...           No           No           No
# 28814          No          No  ...           No           No          Yes
# 28823          No          No  ...           No           No          Yes
#
#          weight  gender age     region_state household_size  \
# 103    1.007474    Male  54  Quebec / Québec     Don't know
# 110    1.012842    Male  34  Quebec / Québec              1
# 127    0.992531    Male  36          Ontario              4
# 128    0.994496  Female  64          Ontario              2
# 134    0.984166  Female  36          Ontario              3
# ...         ...     ...  ..              ...            ...
# 28789  0.683871    Male  26       Washington              5
# 28805  0.566747    Male  20         New York              6
# 28811  0.744511  Female  23             Ohio              4
# 28814  1.302322    Male  18         New York              5
# 28823  2.919237    Male  22      Mississippi              5
#
#       household_children     employment_status
# 103                    1  Full time employment
# 110                    1            Unemployed
# 127                    4  Full time employment
# 128                    0           Not working
# 134                    1  Full time employment
# ...                  ...                   ...
# 28789                  3     Full time student
# 28805                  3  Full time employment
# 28811                  2  Full time employment
# 28814                  2  Part time employment
# 28823                  0  Full time employment
#
# [1795 rows x 75 columns]

# %%
df_clean = pd.DataFrame()
df_final = df_final.reset_index(drop = True)

# %%
df_final["i5_health_1"].apply(lambda x: enc_dict[x] if x in enc_dict.keys() else x)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1790    1
# 1791    0
# 1792    1
# 1793    0
# 1794    0
# Name: i5_health_1, Length: 1795, dtype: object

# %%
df_clean['test'] = df_final["i5_health_1"].apply(lambda x: enc_dict[x] if x in enc_dict.keys() else x)
df_clean
# Out:
#      test
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
# ...   ...
# 1790    1
# 1791    0
# 1792    1
# 1793    0
# 1794    0
#
# [1795 rows x 1 columns]

# %%
for col in df_col:
    print(col)
    df_clean[col] = df_final[col].apply(lambda x: enc_dict[x] if x in enc_dict.keys() else x)
# Out:
# i1_health
# i2_health
# i7a_health
# i3_health
# i4_health
# i5_health_1
# i5_health_2
# i5_health_3
# i5_health_4
# i5_health_5
# i5_health_99
# i5a_health
# i6_health
# i7b_health
# i8_health
# i9_health
# i10_health
# i11_health
# i12_health_1
# i12_health_2
# i12_health_3
# i12_health_4
# i12_health_5
# i12_health_6
# i12_health_7
# i12_health_8
# i12_health_9
# i12_health_10
# i12_health_11
# i12_health_12
# i12_health_13
# i12_health_14
# i12_health_15
# i12_health_16
# i12_health_17
# i12_health_18
# i12_health_19
# i12_health_20
# i13_health
# i14_health_1
# i14_health_2
# i14_health_3
# i14_health_4
# i14_health_5
# i14_health_6
# i14_health_7
# i14_health_8
# i14_health_9
# i14_health_10
# i14_health_96
# i14_health_98
# i14_health_99
# i14_health_other
# d1_health_1
# d1_health_2
# d1_health_3
# d1_health_4
# d1_health_5
# d1_health_6
# d1_health_7
# d1_health_8
# d1_health_9
# d1_health_10
# d1_health_11
# d1_health_12
# d1_health_13
# d1_health_98
# d1_health_99
# weight
# gender
# age
# region_state
# household_size
# household_children
# employment_status

# %%
df_clean['i12_health_2'].value_counts()
# Out:
# Always        1067
# Frequently     406
# Sometimes      193
# Rarely          87
# Not at all      42
# Name: i12_health_2, dtype: int64

# %%
'i3_health''i4_health''i6_health''i10_health''i11_health''i12_health_1'...
'i5a_health''i8_health''i9_health' - 1, 0, 'not sure'

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1795 entries, 0 to 1794
# Data columns (total 75 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   i1_health           1795 non-null   int64
#  1   i2_health           1795 non-null   int64
#  2   i7a_health          1795 non-null   int64
#  3   i3_health           1795 non-null   object
#  4   i4_health           1795 non-null   object
#  5   i5_health_1         1795 non-null   object
#  6   i5_health_2         1795 non-null   object
#  7   i5_health_3         1795 non-null   object
#  8   i5_health_4         1795 non-null   object
#  9   i5_health_5         1795 non-null   object
#  10  i5_health_99        1795 non-null   object
#  11  i5a_health          1795 non-null   object
#  12  i6_health           1795 non-null   object
#  13  i7b_health          1795 non-null   object
#  14  i8_health           1795 non-null   object
#  15  i9_health           1795 non-null   object
#  16  i10_health          1795 non-null   object
#  17  i11_health          1795 non-null   object
#  18  i12_health_1        1795 non-null   object
#  19  i12_health_2        1795 non-null   object
#  20  i12_health_3        1795 non-null   object
#  21  i12_health_4        1795 non-null   object
#  22  i12_health_5        1795 non-null   object
#  23  i12_health_6        1795 non-null   object
#  24  i12_health_7        1795 non-null   object
#  25  i12_health_8        1795 non-null   object
#  26  i12_health_9        1795 non-null   object
#  27  i12_health_10       1795 non-null   object
#  28  i12_health_11       1795 non-null   object
#  29  i12_health_12       1795 non-null   object
#  30  i12_health_13       1795 non-null   object
#  31  i12_health_14       1795 non-null   object
#  32  i12_health_15       1795 non-null   object
#  33  i12_health_16       1795 non-null   object
#  34  i12_health_17       1795 non-null   object
#  35  i12_health_18       1795 non-null   object
#  36  i12_health_19       1795 non-null   object
#  37  i12_health_20       1795 non-null   object
#  38  i13_health          1795 non-null   int64
#  39  i14_health_1        1795 non-null   object
#  40  i14_health_2        1795 non-null   object
#  41  i14_health_3        1795 non-null   object
#  42  i14_health_4        1795 non-null   object
#  43  i14_health_5        1795 non-null   object
#  44  i14_health_6        1795 non-null   object
#  45  i14_health_7        1795 non-null   object
#  46  i14_health_8        1795 non-null   object
#  47  i14_health_9        1795 non-null   object
#  48  i14_health_10       1795 non-null   object
#  49  i14_health_96       1795 non-null   object
#  50  i14_health_98       1795 non-null   object
#  51  i14_health_99       1795 non-null   object
#  52  i14_health_other    1795 non-null   object
#  53  d1_health_1         1795 non-null   object
#  54  d1_health_2         1795 non-null   object
#  55  d1_health_3         1795 non-null   object
#  56  d1_health_4         1795 non-null   object
#  57  d1_health_5         1795 non-null   object
#  58  d1_health_6         1795 non-null   object
#  59  d1_health_7         1795 non-null   object
#  60  d1_health_8         1795 non-null   object
#  61  d1_health_9         1795 non-null   object
#  62  d1_health_10        1795 non-null   object
#  63  d1_health_11        1795 non-null   object
#  64  d1_health_12        1795 non-null   object
#  65  d1_health_13        1795 non-null   object
#  66  d1_health_98        1795 non-null   object
#  67  d1_health_99        1795 non-null   object
#  68  weight              1795 non-null   float64
#  69  gender              1795 non-null   object
#  70  age                 1795 non-null   int64
#  71  region_state        1795 non-null   object
#  72  household_size      1795 non-null   object
#  73  household_children  1795 non-null   object
#  74  employment_status   1795 non-null   object
# dtypes: float64(1), int64(5), object(69)
# memory usage: 1.0+ MB

# %%
df_clean = df_clean.replace(" ", np.nan)
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1795 entries, 0 to 1794
# Data columns (total 75 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   i1_health           1795 non-null   int64
#  1   i2_health           1795 non-null   int64
#  2   i7a_health          1795 non-null   int64
#  3   i3_health           1795 non-null   object
#  4   i4_health           1701 non-null   object
#  5   i5_health_1         1736 non-null   float64
#  6   i5_health_2         1736 non-null   float64
#  7   i5_health_3         1736 non-null   float64
#  8   i5_health_4         1736 non-null   float64
#  9   i5_health_5         1736 non-null   float64
#  10  i5_health_99        1736 non-null   float64
#  11  i5a_health          669 non-null    object
#  12  i6_health           669 non-null    object
#  13  i7b_health          574 non-null    float64
#  14  i8_health           578 non-null    object
#  15  i9_health           1657 non-null   object
#  16  i10_health          1657 non-null   object
#  17  i11_health          1657 non-null   object
#  18  i12_health_1        1795 non-null   object
#  19  i12_health_2        1795 non-null   object
#  20  i12_health_3        1795 non-null   object
#  21  i12_health_4        1795 non-null   object
#  22  i12_health_5        1795 non-null   object
#  23  i12_health_6        1795 non-null   object
#  24  i12_health_7        1795 non-null   object
#  25  i12_health_8        1795 non-null   object
#  26  i12_health_9        1071 non-null   object
#  27  i12_health_10       1111 non-null   object
#  28  i12_health_11       1795 non-null   object
#  29  i12_health_12       1795 non-null   object
#  30  i12_health_13       1795 non-null   object
#  31  i12_health_14       1795 non-null   object
#  32  i12_health_15       1795 non-null   object
#  33  i12_health_16       1795 non-null   object
#  34  i12_health_17       1795 non-null   object
#  35  i12_health_18       1795 non-null   object
#  36  i12_health_19       1795 non-null   object
#  37  i12_health_20       1795 non-null   object
#  38  i13_health          1795 non-null   int64
#  39  i14_health_1        1071 non-null   float64
#  40  i14_health_2        1071 non-null   float64
#  41  i14_health_3        1071 non-null   float64
#  42  i14_health_4        1071 non-null   float64
#  43  i14_health_5        1071 non-null   float64
#  44  i14_health_6        1071 non-null   float64
#  45  i14_health_7        1071 non-null   float64
#  46  i14_health_8        1071 non-null   float64
#  47  i14_health_9        1071 non-null   float64
#  48  i14_health_10       1071 non-null   float64
#  49  i14_health_96       1071 non-null   float64
#  50  i14_health_98       1071 non-null   float64
#  51  i14_health_99       1071 non-null   float64
#  52  i14_health_other    1795 non-null   object
#  53  d1_health_1         1660 non-null   float64
#  54  d1_health_2         1660 non-null   float64
#  55  d1_health_3         1660 non-null   float64
#  56  d1_health_4         1660 non-null   float64
#  57  d1_health_5         1660 non-null   float64
#  58  d1_health_6         1660 non-null   float64
#  59  d1_health_7         1660 non-null   float64
#  60  d1_health_8         1660 non-null   float64
#  61  d1_health_9         1660 non-null   float64
#  62  d1_health_10        1660 non-null   float64
#  63  d1_health_11        1660 non-null   float64
#  64  d1_health_12        1660 non-null   float64
#  65  d1_health_13        1660 non-null   float64
#  66  d1_health_98        1660 non-null   float64
#  67  d1_health_99        1660 non-null   float64
#  68  weight              1795 non-null   float64
#  69  gender              1795 non-null   object
#  70  age                 1795 non-null   int64
#  71  region_state        1795 non-null   object
#  72  household_size      1795 non-null   object
#  73  household_children  1795 non-null   object
#  74  employment_status   1795 non-null   object
# dtypes: float64(36), int64(5), object(34)
# memory usage: 1.0+ MB

# %% [markdown]
# # Problems to handle
#
# ## 1. How to proceed with the data cleaning (1-yes, 2-no, 3-not sure...?)
#
# ## 2. What about other columns with different text value (one-hot encoding?)
#
# ## 3. Are the selection of features and target ok?
#
# ## 4. What is the threshold for determing overfitting for KNN regression? (PCA needed?)

# %%
# Determine the columns for X and columns for y
X = df_final.drop(["i3_health"], axis = 1)
y = df_final["i3_health"]

# %%
# Split the data into training and testing datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 1)

# %%
# Scale the data
scaler = StandardScaler().fit(X_train)
rescaledX_train = scaler.transform(X_train)

# %%
# Initialize k lvaues
k_values = np.arange(1, 25)

# %%
# Train to find the best value for k
param_grid = dict(n_neighbors = k_values)

# %%
# Create a KNN model object
model = KNeightborsRegressor()
kfd = KFold(n_splits = 10, shuffle = True, random_state = 1)

# %%
# GridSearch
grid = GridSearchCV(estimator = model, param_grid = param_grid, scoring = 'neg_mean_squared_error', cv = kfd)

# %%
# Output the GridSearch result
grid_result = grid.fit(rescaledX_train, y_train)

# %%
# Print the result
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))

# %%
# Check some parameters of the grid search results
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    print("%f (%f) with: %r" % (mean, stdev, param))

# %%
# Plot the score out for better view results
plt.plot(k_values, means)
plt.xlabel("Number of Neighbors K")
plt.ylabel("Negative Mean Squared Error")
plt.show()

# %%
# With knowing the optimal value for K
scaler = StandardScale(). fit(X_train)

rescaledX_train = scaler.transform(X_train)

# %%
# Fit in the best number of neighbors
model = KNeighborsRegressor(n_neighbors = TBD)

# %%
# Fit into the scaled values.
model.fit(rescaledX_train, y_train)

# %%
# Fill in the Test data
rescaledX_test = scaler.transform(X_test)

# %%
# Make the prediction using the trained model
estimates = model.predict(rescaledX_test)

# %%
# Check how good the model is
mean_squared_error(y_test, estimates)
